# %%
# 숫자형(NumberType): 숫자로 이루어진 자료형으로
# 123과 같은 정수, 12.34와 같은 실수, 8진법 16진법 등이다.

# 정수형(integer) : 양의 정수, 음의 정수, 0
a = 123
print(a) # 양의 정수
# Out:
# 123

# %%
b = -123
print(b) # 음의 정수
# Out:
# -123

# %%
# 실수형(floating-point) : 소수점이 포함된 숫자
c = 1.2
print(c)
# Out:
# 1.2

# %%
d = -3.45
print(d) # 음의 실수
# Out:
# -3.45

# %%
# 지수형식 (과학기술용) 엄청큰 실수 들   e가들어가면 지수형식 이다
e = 4.24E10 # 42,400,000,000 424억
print(e)
# Out:
# 42400000000.0

# %%
f = 4.24e-10 # 0.000000000424
print(f)
# Out:
# 4.24e-10

# %%
# 8진수(octal) 입력 기법
# 숫자0과 영문자 o를 쓰고 입력
g = 0o177 #8진법 177
print(g)
# Out:
# 127

# %%
# 1진법(hexadecimal) 0x로 입력
h = 0x8ff
print(h)
# Out:
# 2303

# %%
# 사칙연산
# a+b 더하기
# a-b 빼기
# a*b 곱하기
# a**b 제곱
4**2
# Out:
# 16

# %%
# a/b 나누기
5/2
# Out:
# 2.5

# %%
5//2 #몫을 구함
# Out:
# 2

# %%
5%2 #나머지를 구함
# Out:
# 1

# %%
# 복합 연산자
# 산술연산자와 대입연산자를 합쳐 놓음
i = 0
i = i + 1 # i변수에 1을 더하고 i에 넣어라 라는 뜻
print(i)
# Out:
# 1

# %%
i += 1 # i = i + 1 을 줄인것
print(i)
# Out:
# 2

# %%
i -= 1 # i = - 1을 줄인형태
print(i)
# Out:
# 1

# %%
i *= 5 # i = i * 5
print(i)
# Out:
# 5

# %%
# +=, -=, *=, /=, //=, %=, **= 들이 있다.
