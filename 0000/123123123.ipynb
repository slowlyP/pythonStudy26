# %%
shirt = {'1.줄무늬티셔츠' : 20000, '2.흰와이셔츠' : 10000}
shirt['1.줄무늬티셔츠']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 shirt = {'1'.줄무늬티셔츠 : 20000, '2.흰와이셔츠' : 10000}
#       2 shirt['1']
#
# AttributeError: 'str' object has no attribute '줄무늬티셔츠'
